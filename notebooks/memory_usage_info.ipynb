# %%
import os
import psutil

# %%
# reference: https://psutil.readthedocs.io/en/latest/index.html?highlight=memory_info#psutil.Process.memory_info
# https://stackoverflow.com/questions/7880784/what-is-rss-and-vsz-in-linux-memory-management
pid = os.getpid()
ps = psutil.Process(pid)
# Out:
# 8762

# %%
# get memory use info:

# usage:
# before_memory = ps.memory_info()
# run_some_processes()
# after memory = ps.memory_info()

# we only need to focus on is rss and vms
# rss: Resident Set Size, this is the non-swapped physical memory a process has used.
# vms: Virtual Memory Size, this is the total amount of virtual memory used by the process.
memory_usage = after_memory - before_memory
print(f'the total memory consumed is: {memory_usage} bytes')

# used dot method: memory_usage.rss
# >>> 953290752
# or print(memory_usage)
# >>> pmem(rss=953290752, vms=1925992448, shared=46641152, text=2330624, lib=0, data=1261969408, dirty=0)
